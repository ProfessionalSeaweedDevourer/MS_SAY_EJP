# %%
# GD: Local Minimum 문제 => 진짜 최솟값이 아니라 '그 동네에서의 최솟값'에 갇힐 수 있음

# SGD: Stochastic GD => 원소 중 하나씩을 무작위로 빼서 반복 => 의외성으로 Local Minimum을 해결

# Mini-batch SGD => 동시에 여러 원소를 보고 방향 결정
# => batch size = 2 등으로 지정 (하이퍼패러미터)

# * 개념 정리
# 패러미터: AI가 찾아내야 하는 값 (가중치, 편향 등)
# 하이퍼패러미터: 사람이 지정해야 진행할 수 있는 값 (학습률, 배치 사이즈, 에폭 등)

# %%
import tensorflow as tf

tf.compat.v1.disable_v2_behavior() # 여기까지가 템플런임
# Out:
# WARNING:tensorflow:From C:\Users\soldesk\AppData\Local\Temp\ipykernel_11708\2913416458.py:3: The name tf.disable_v2_behavior is deprecated. Please use tf.compat.v1.disable_v2_behavior instead.
#
# WARNING:tensorflow:From c:\Users\soldesk\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\python\compat\v2_compat.py:98: disable_resource_variables (from tensorflow.python.ops.resource_variables_toggle) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
# 1) 데이터

xData = [1, 2, 3]
yData = []

# %%
# 2)

loss = 

o = tf.compat.v1.train.AdamOptimizer(learning_rate=0.1) 

goal = o.minimize(loss)

# %%
# 3)

# %%
# 4)
