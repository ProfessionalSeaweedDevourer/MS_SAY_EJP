# %% [markdown]
# ## 준비물
#
# #### 애드온 관리자 yarn 설치
# ```npm install yarn -g```
#
# #### React 대비 VSC 확장 설치
# * ESLint: JS계 자동완성
# * Prettier: JS계 코드 정렬
# * ES7 + React : React계 자동완성

# %% [markdown]
# ## 주요 파일 내용
#
# * ```public/index.html```: ```<div id="root"></div>``` Root 영역 존재
# * ```src/index.js```: 기본 설정 & Root에 ```App.js``` 띄우기
# * ```src/App.js```: 실제 작업 영역
# * ```src/App.css```: 실제 작업 영역의 디자인

# %% [markdown]
# ## React 프로젝트 생성
# ```yarn create vite```
#
# 프로젝트명 > React > JS > no > yes
#
# 대문자 넣으면 패키지명 오류 뜸
#
# #### 프로젝트 실행 / 빌드
# ```cd 프로젝트명```
#
# ```yarn start```
# * package.json 내부 script.start에 있는 명령어를 실행.

# %% [markdown]
# ##### **테스트 빌드에서 80번 포트를 쓰는 이유**
# HTTP 기본 포트가 80번이라, 따로 포트 지정 안 하면 바로 연결.
#
# ##### **8080을 대신 쓰는 이유**
# Linux에서는 1024번 이하의 포트는 root 권한 있어야 바인딩 가능해서 불편함
#
# OracleDB도 8080 씀(아오)

# %% [markdown]
# ## 클래식 웹 vs 신형 웹
#
# 클래식 웹
#  * 메인 서버 하나에 부하가 너무 많이 걸림
#  * 분업화의 어려움: 데이터를 여러 군데에서 가져오기에는 신형 웹이 적합

# %% [markdown]
# ## React의 의의
#
# 외부 클래스 및 메소드를 만들어서 태그처럼 불러와서 쓰기.

# %% [markdown]
# #### alt+z로 분할 화면 크기에 맞게 내용 출력.

# %% [markdown]
# ## 12/17 - 12/18 미니 프로젝트: 웹 게시판
#
# * DB와 연동되는 '메뉴'를 보여주는 React 프론트엔드.
#     * '메뉴' 항목 메뉴명, 가격, 설명을 본 페이지에서 추가 가능.
#     * 자주 업데이트되는 본 페이지 구현에 있어 Virtual DOM이 유용.
#     * useState로 입력값과 리스트 관리.
#     * useEffect & Axios로 백엔드 API 데이터 수신.
# * FastAPI 기반 백엔드.
#     * 외부 OracleDB DB와 연결하고 데이터 연동.
#
# #### 새로 배운 것들
# * .env 환경 파일: gitignore에 추가하고, 민감한 데이터 (API키, 서버 관련 정보 등) 따로 관리하며 필요할 때 불러오기.
# * SQLAlchemy python 라이브러리: sql문을 수동으로 작성하지 않아도 됨. 또한 DB를 python 클래스로 취급 (Object-Relation Mapping)
