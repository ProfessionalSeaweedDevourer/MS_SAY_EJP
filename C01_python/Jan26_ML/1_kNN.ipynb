# %% [markdown]
#  AI-900 : MS Azure Machine Learning/AI
#
#
#   AI-900 문제 예제
#  ~~~~는 어떤 분야의 문제인가
#  1) 분류
#  2) 클러스터링
#
#
#  MS Azure : MS Cloud(MS의 컴퓨터를 빌려서 쓸 수 있는) 생태계
#  MS Azure VM : MS의 쌩 컴 빌려서 쓸 수 있는 (IaaS)
#  MS Azure Machine Learning
#        Python DB/AI작업환경이 다 갖춰져 있는 MS의 빌려서 쓸 수 있는
#        PaaS
#  MS Azure AI
#        아예 만들어져있는 AI 모델 갖다 쓸 수 있는 환경
#        PaaS(SaaS느낌도 좀 있음)
#  MS Power Platfor
#        노코딩 프론트앤드 개발환경
#        PaaS
#
#  AI
#    Machine Learning :
#        문제 해결하는데 필요한 알고리즘을 사람이 골라주자
#        데이터 기반
#        분야별 ML알고리즘 몇개 소개
#            뭔지 알았으니 라이브러리 쓰자
#                ->  Python ML lib Scikit-learn
#
#    Deep Learning
#        문제 해결하는데 필요한 알고리즘도 AI가 찾아내게
#
#
#  지도학습(분류) : 데이터(feature + label) 데이터를 학습시켜서
#                미지의 데이터에 대한 결론
#
#  비지도학습(클러스터링) : 데이터를 줄테니 알아서

# %%
import numpy as np
 
featuree =np.array([[80,20],[95,5],[10,90],[90,10],[5,95]])
labell = np.array(["액션","액션","조폭","액션","조폭"])

# %%
fight = float(input('격투씬 : '))
yok = float(input('욕씬 : '))
 
z = np.array([[fight,yok]])
result = knc.predict(z) #예측하기
print(result[0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 fight = float(input('격투씬 : '))
#       2 yok = float(input('욕씬 : '))
#       4 z = np.array([[fight,yok]])
#
# ValueError: could not convert string to float: ''
