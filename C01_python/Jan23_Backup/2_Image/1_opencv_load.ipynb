# %%
# %pip install opencv-python

# %%
import cv2

a = cv2.imread("./Users/student02_04/Jan23_1_Text/2_image/cursed-cat.jpg", cv2.IMREAD_GRAYSCALE)
print(a) # 그레이스케일로만 > 흑백 명확히

b = cv2.imread("./Users/student02_04/Jan23_1_Text/2_image/cursed-cat.jpg", cv2.IMREAD_COLOR)
b = cv2.cvtColor(b, cv2.COLOR_BGR2RGB) #각 픽셀을 b / g / r 순으로 값으로 읽기 때문에 RGB순으로 재배열
print(b)
